# %%
# !python train_cls.py --nepoch 100 --model_path "../../pretrain/pre_trained_3d_point/pre_trained_pointnet.pth" --dataset_type "modelnet40" --dataset_path "../../dataset/ModelNet40_blender_sampling_1024/ModelNet40_blender_sampling_1024/" --log_dir "resnet_unfrozen_model_downstream_2/"
# Out:
# 2023-05-25 17:50:19.396355: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-25 17:50:20.747818: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# None
# Random Seed:  6219
# 9843 2468
# classes 40
# ...
# Restored Params and Shapes:
# mlp1.0.bias :  torch.Size([64])
# mlp1.1.weight :  torch.Size([64])
# mlp1.1.bias :  torch.Size([64])
# mlp1.1.running_mean :  torch.Size([64])
# mlp1.1.running_var :  torch.Size([64])
# mlp1.1.num_batches_tracked :  torch.Size([])
# mlp1.4.num_batches_tracked :  torch.Size([])
# mlp2.1.num_batches_tracked :  torch.Size([])
# mlp2.4.num_batches_tracked :  torch.Size([])
# ...
# None using weight decay
# BN momentum updated to: 0.500000 learning rate: 0.001000
# ...
